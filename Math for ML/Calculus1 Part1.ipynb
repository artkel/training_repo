# %% [markdown]
# # Calculus I: Mathematical Study of continious change

# %%
import numpy as np
import torch
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Segment 1: Limits

# %% [markdown]
# ### The Calculus of Infinitesimals

# %%
x = np.linspace(-10, 10, 10000) # start, finish, n points

# %%
y = x**2 + 2*x + 2

# %%
fig, ax = plt.subplots()
_ = ax.plot(x,y)

# %% [markdown]
# * There are no straight lines on the curve.
# * If we zoom in _infinitely_ close, however, we observe curves that _approach_ lines.
# * This enables us to find a slope $m$ (tangent) anywhere on the curve, including to identify where $m = 0$:

# %%
fig, ax = plt.subplots()
ax.set_xlim([-2, -0])
ax.set_ylim([0, 2])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.5, -0.5])
ax.set_ylim([0.5, 1.5])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.1, -0.9])
ax.set_ylim([0.9, 1.1])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.01, -0.99])
ax.set_ylim([0.99, 1.01])
_ = ax.plot(x,y)

# %% [markdown]
# ### Limits

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-5, 10)
plt.ylim(-10, 80)
plt.axvline(x=5, color='purple', linestyle='--')
plt.axhline(y=37, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# $$\lim_{x \to 1} \frac{x^2 - 1}{x - 1}$$

# %%
def my_fxn(my_x):
    my_y = (my_x**2 - 1)/(my_x - 1)
    return my_y

# %%
my_fxn(2)
# Out:
# 3.0

# %%
# Uncommenting the following line results in a 'division by zero' error:
# my_fxn(1)

# %%
my_fxn(0.9)
# Out:
# 1.9

# %%
my_fxn(0.999)
# Out:
# 1.9989999999999712

# %%
my_fxn(1.001)
# Out:
# 2.0009999999999177

# %%
y = my_fxn(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-1, 5)
plt.ylim(-1, 5)
plt.axvline(x=1, color='purple', linestyle='--')
plt.axhline(y=2, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# $$\lim_{x \to 0} \frac{\text{sin } x}{x}$$

# %%
def sin_fxn(my_x):
    my_y = np.sin(my_x)/my_x
    return my_y

# %%
# Uncommenting the following line results in a 'division by zero' error:
# y = sin_fxn(0)

# %%
sin_fxn(0.1)
# Out:
# 0.9983341664682815

# %%
sin_fxn(0.001)
# Out:
# 0.9999998333333416

# %%
y = sin_fxn(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-1, 2)
plt.axvline(x=0, color='purple', linestyle='--')
plt.axhline(y=1, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %% [markdown]
# ## Segment 2: Calculating Derivatives with Differentiation

# %% [markdown]
# $y = x^2 + 2x + 2$

# %%
def f(my_x):
    my_y = my_x**2 + 2*my_x + 2
    return my_y

# %%
y = f(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
_ = ax.plot(x,y)

# %% [markdown]
# Excercise 1: Using the delta method calculate the slope of the tangent where x = -1

# %%
x1 = -1

# %%
y1 = f(x1)
y1
# Out:
# 1

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(x1, y1) # new
_ = ax.plot(x,y)

# %%
x2 = -0.999999
y2 = f(x2)
y2
# Out:
# 1.000000000001

# %% [markdown]
# To find the slope $m$ between points $P$ and $Q$:
# $$m = \frac{\text{change in }y}{\text{change in }x} = \frac{\Delta y}{\Delta x} = \frac{y_2 - y_1}{x_2 - x_1} = \frac{37-10}{5-2} = \frac{27}{3} = 9$$

# %%
m =  (y2-y1) / (x2-x1)
m # m = 0
# Out:
# 1.0000889005535828e-06

# %% [markdown]
# Therefore, as $x_2$ becomes infinitely close to $x_1$, it becomes clear that the slope $m$ at $x_1 = -1$ is equal to zero. Let's plot it out:

# %%
# finding intercept
b = y2-m*x2
b
# Out:
# 1.0000010000889006

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(x1, y1)
plt.scatter(x2, y2, c='orange', zorder=3)
plt.ylim(-5, 150)
plt.plot(x, line_y, c='orange', zorder=3)
_ = ax.plot(x,y)

# %% [markdown]
# Excercise 2: Using the delta method calculate the slope of the tangent where x = 2

# %%
x1 = 2
x_delta = .000001
x2 = x1 + x_delta
y1, y2 = f(x1), f(x1 + x_delta)

# %%
# find the slope
m = (y2 - y1) / (x2 - x1)
print(m)
# Out:
# 6.000001000088901

# %%
# finding intercept
b = y2-m*x2
print(b)
# Out:
# -2.000002000177801

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(x1, y1)
plt.scatter(x2, y2, c='orange', zorder=3)
plt.ylim(-5, 150)
plt.plot(x, line_y, c='orange', zorder=3)
_ = ax.plot(x,y)

# %% [markdown]
# As $Q$ becomes infinitely close to $P$:
# * $x_2$ - $x_1$ approaches 0
# * In other words, $\Delta x$ approaches 0
# * This can be denoted as $\Delta x \to 0$

# %% [markdown]
# Using the delta method, we've derived the definition of differentiation from first principles. The derivative of $y$ (denoted $dy$) with respect to $x$ (denoted $dx$) can be represented as:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{\Delta y}{\Delta x}$$

# %% [markdown]
# Expanding $\Delta y$ out to $y_2 - y_1$:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{y_2 - y_1}{\Delta x}$$

# %% [markdown]
# Finally, replacing $y_1$ with $f(x)$ and replacing $y_2$ with $f(x + \Delta x)$, we obtain a common representation of differentiation:
# $$\frac{dy}{dx} = \lim_{\Delta x \to 0} \frac{f(x + \Delta x) - f(x)}{\Delta x}$$

# %% [markdown]
# ## Segment 3: Automatic Differentiation

# %% [markdown]
# **TensorFlow** and **PyTorch** are the two most popular automatic differentiation libraries.

# %% [markdown]
# Let's use them to calculate $dy/dx$ at $x = 5$ where:

# %% [markdown]
# $$y = x^2$$

# %% [markdown]
# $$ \frac{dy}{dx} = 2x = 2(5) = 10 $$

# %% [markdown]
# #### PyTorch

# %%
x = torch.tensor(5.0)
x
# Out:
# tensor(5.)

# %%
x.requires_grad_() # contagiously track gradients through forward pass
# Out:
# tensor(5., requires_grad=True)

# %%
y = x**2

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(10.)

# %%
y1 = 5*x**4 - 1/x - .5*x**3 + 2*x - 9

# %%
y1.backward()

# %%
x.grad
# Out:
# tensor(2474.5400)

# %% [markdown]
# #### TensorFlow

# %%
x = tf.Variable(5.0)

# %%
with tf.GradientTape() as t:
    t.watch(x) # track forward pass
    y = x**2

# %%
t.gradient(y, x) # use autodiff
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.0>
